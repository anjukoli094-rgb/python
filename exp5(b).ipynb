# %%
tup1=(10,20,30,20,40,50)
print(len(tup1))
# Out:
# 6

# %%
print(type(tup1))
# Out:
# <class 'tuple'>

# %%
num1=[10,20,30]
print(type(num1))
# Out:
# <class 'list'>

# %%
num=('a' ,)
print(type(num))
# Out:
# <class 'tuple'>

# %%
print(tup1.index(20))
# Out:
# 1

# %%
print(tup1.count(20))
# Out:
# 2

# %%
print(max(tup1))
# Out:
# 50

# %%
print(min(tup1))
# Out:
# 10

# %%
print(sorted(tup1))
# Out:
# [10, 20, 20, 30, 40, 50]
