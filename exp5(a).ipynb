# %%
fruits=["apple","mango","banana"]
print(fruits)
# Out:
# ['apple', 'mango', 'banana']

# %%
print(fruits[1])
# Out:
# mango

# %%
print(fruits[1:3])
# Out:
# ['mango', 'banana']

# %%
print(len(fruits))
# Out:
# 3

# %%
fruits[1]="orange"
print(fruits)
# Out:
# ['apple', 'orange', 'banana']

# %%
fruits=["apple","mango","banana"]
print(fruits.append("papaya"))
print(fruits)
# Out:
# None
# ['apple', 'mango', 'banana', 'papaya']

# %%
print(type(fruits))
# Out:
# <class 'list'>

# %%
fruits=["apple","mango","banana"]
(fruits.remove("mango"))
print(fruits)
# Out:
# None
# ['apple', 'banana']

# %%
fruits=["apple","mango","banana"]
(fruits.sort())
print(fruits)
# Out:
# ['apple', 'banana', 'mango']

# %%
fruits=["apple","mango","banana"]
fruits.sort(reverse=True)
print(fruits)
# Out:
# ['mango', 'banana', 'apple']

# %%
fruits=["apple","mango","banana"]
fruits.extend("cherry")
print(fruits)
# Out:
# ['apple', 'mango', 'banana', 'c', 'h', 'e', 'r', 'r', 'y']

# %%
fruits=["apple","mango","banana"]
fruits.insert(1,"cherry")
print(fruits)
# Out:
# ['apple', 'cherry', 'mango', 'banana']
